# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import pandas as pd

# Set font and fontsize globally
matplotlib.rcParams['font.family'] = 'Arial'
matplotlib.rcParams['font.size'] = 11

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv('summary_flask.csv', skiprows=[0,1])

# select randomly 50 rows from the summary_flask dataframe
summary_flask = summary_flask.sample(n=50)

# write to new csv file
# add first row with column names
summary_flask.to_csv('summary_flask_test.csv', header=['scene_number','path','rotationSpeed','stop_angle','pause_time','volume_start','volume_poured','volume_received','spilled_volume'], index=False)

#'real_poured_volume', 'real_received_volume', 'real_spilled_volume'

# add the real_poured_volume, real_received_volume, real_spilled_volume columns
summary_flask = pd.read_csv('summary_flask_test.csv')
summary_flask['real_poured_volume'] = summary_flask['volume_poured']*0.0
summary_flask['real_received_volume'] = summary_flask['volume_poured']*0.0
summary_flask['real_spilled_volume'] = summary_flask['volume_poured']*0.0

# write to new csv file
summary_flask.to_csv('summary_flask_test.csv', index=False)
# Out:
# Sample_folder: ../../output/CellFlask/Flask_115_200_10  Starting_volume: 111.1875 , Poured_volume: 15.10025 , Stop_angle: 10.0 , Stop_time: 0.2
#
# Sample_folder: ../../output/CellFlask/Flask_120_1399_12  Starting_volume: 116.1075 , Poured_volume: 34.47125 , Stop_angle: 12.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_25_1399_38  Starting_volume: 24.3825 , Poured_volume: 24.172500000000003 , Stop_angle: 38.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_35_1000_32  Starting_volume: 34.0325 , Poured_volume: 31.762500000000003 , Stop_angle: 32.0 , Stop_time: 1.0
#
# Sample_folder: ../../output/CellFlask/Flask_15_1399_14  Starting_volume: 14.6925 , Poured_volume: 1.0120000000000002 , Stop_angle: 14.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_80_1399_30  Starting_volume: 77.265 , Poured_volume: 77.14850220000001 , Stop_angle: 30.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_80_600_18  Starting_volume: 77.265 , Poured_volume: 42.84224780000001 , Stop_angle: 18.0 , Stop_time: 0.6
#
# Sample_folder: ../../output/CellFlask/Flask_35_1000_28  Starting_volume: 34.0325 , Poured_volume: 28.371750000000002 , Stop_angle: 28.0 , Stop_time: 1.0
#
# Sample_folder: ../../output/CellFlask/Flask_85_1000_18  Starting_volume: 82.1 , Poured_volume: 48.278998900000005 , Stop_angle: 18.0 , Stop_time: 1.0
#
# Sample_folder: ../../output/CellFlask/Flask_65_600_12  Starting_volume: 62.72 , Poured_volume: 8.549750000000001 , Stop_angle: 12.0 , Stop_time: 0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_135_1000_44 , Starting_volume:  130.565 , Poured_volume:  130.565 , Stop_angle:  44.0 , Stop_time:  1.0
#
# Sample_folder: ../../output/CellFlask/Flask_60_600_20  Starting_volume: 57.91 , Poured_volume: 33.60775 , Stop_angle: 20.0 , Stop_time: 0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_60_1399_34 , Starting_volume:  57.91 , Poured_volume:  57.91 , Stop_angle:  34.0 , Stop_time:  1.4
#
# Sample_folder:  ../../output/CellFlask/Flask_75_200_40 , Starting_volume:  72.375 , Poured_volume:  72.375 , Stop_angle:  40.0 , Stop_time:  0.2
#
# Sample_folder: ../../output/CellFlask/Flask_80_1000_30  Starting_volume: 77.265 , Poured_volume: 76.8239956 , Stop_angle: 30.0 , Stop_time: 1.0
#
# Sample_folder: ../../output/CellFlask/Flask_30_1799_28  Starting_volume: 29.2125 , Poured_volume: 24.070750000000004 , Stop_angle: 28.0 , Stop_time: 1.8
#
# Sample_folder: ../../output/CellFlask/Flask_120_1399_18  Starting_volume: 116.1075 , Poured_volume: 78.7462522 , Stop_angle: 18.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_150_1799_6  Starting_volume: 144.92 , Poured_volume: 7.306750000000001 , Stop_angle: 6.0 , Stop_time: 1.8
#
# Sample_folder:  ../../output/CellFlask/Flask_125_600_36 , Starting_volume:  120.855 , Poured_volume:  120.855 , Stop_angle:  36.0 , Stop_time:  0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_115_200_34 , Starting_volume:  111.1875 , Poured_volume:  111.1875 , Stop_angle:  34.0 , Stop_time:  0.2
#
# Sample_folder:  ../../output/CellFlask/Flask_80_1000_50 , Starting_volume:  77.265 , Poured_volume:  77.265 , Stop_angle:  50.0 , Stop_time:  1.0
#
# Sample_folder:  ../../output/CellFlask/Flask_70_600_34 , Starting_volume:  67.5025 , Poured_volume:  67.5025 , Stop_angle:  34.0 , Stop_time:  0.6
#
# Sample_folder: ../../output/CellFlask/Flask_85_200_24  Starting_volume: 82.1 , Poured_volume: 69.0002511 , Stop_angle: 24.0 , Stop_time: 0.2
#
# Sample_folder:  ../../output/CellFlask/Flask_140_600_28 , Starting_volume:  135.44 , Poured_volume:  135.44 , Stop_angle:  28.0 , Stop_time:  0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_110_1399_46 , Starting_volume:  106.2375 , Poured_volume:  106.2375 , Stop_angle:  46.0 , Stop_time:  1.4
#
# Sample_folder:  ../../output/CellFlask/Flask_120_1399_28 , Starting_volume:  116.1075 , Poured_volume:  116.1075 , Stop_angle:  28.0 , Stop_time:  1.4
#
# Sample_folder:  ../../output/CellFlask/Flask_55_600_48 , Starting_volume:  53.15 , Poured_volume:  53.15 , Stop_angle:  48.0 , Stop_time:  0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_150_1399_34 , Starting_volume:  144.92 , Poured_volume:  144.92 , Stop_angle:  34.0 , Stop_time:  1.4
#
# Sample_folder:  ../../output/CellFlask/Flask_145_1399_32 , Starting_volume:  140.1 , Poured_volume:  140.1 , Stop_angle:  32.0 , Stop_time:  1.4
#
# Sample_folder: ../../output/CellFlask/Flask_20_1000_18  Starting_volume: 19.5725 , Poured_volume: 4.5760000000000005 , Stop_angle: 18.0 , Stop_time: 1.0
#
# Sample_folder: ../../output/CellFlask/Flask_15_200_16  Starting_volume: 14.6925 , Poured_volume: 1.5647500000000003 , Stop_angle: 16.0 , Stop_time: 0.2
#
# Sample_folder: ../../output/CellFlask/Flask_110_1399_12  Starting_volume: 106.2375 , Poured_volume: 29.647748900000003 , Stop_angle: 12.0 , Stop_time: 1.4
#
# Sample_folder:  ../../output/CellFlask/Flask_140_600_38 , Starting_volume:  135.44 , Poured_volume:  135.44 , Stop_angle:  38.0 , Stop_time:  0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_70_1799_42 , Starting_volume:  67.5025 , Poured_volume:  67.5025 , Stop_angle:  42.0 , Stop_time:  1.8
#
# Sample_folder: ../../output/CellFlask/Flask_90_600_18  Starting_volume: 86.865 , Poured_volume: 50.4432478 , Stop_angle: 18.0 , Stop_time: 0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_100_600_30 , Starting_volume:  96.6775 , Poured_volume:  96.6775 , Stop_angle:  30.0 , Stop_time:  0.6
#
# Sample_folder: ../../output/CellFlask/Flask_65_1799_10  Starting_volume: 62.72 , Poured_volume: 5.07925 , Stop_angle: 10.0 , Stop_time: 1.8
#
# Sample_folder: ../../output/CellFlask/Flask_125_1799_24  Starting_volume: 120.855 , Poured_volume: 112.37049890000002 , Stop_angle: 24.0 , Stop_time: 1.8
#
# Sample_folder: ../../output/CellFlask/Flask_65_1799_6  Starting_volume: 62.72 , Poured_volume: 0.4675 , Stop_angle: 6.0 , Stop_time: 1.8
#
# Sample_folder:  ../../output/CellFlask/Flask_35_200_38 , Starting_volume:  34.0325 , Poured_volume:  34.0325 , Stop_angle:  38.0 , Stop_time:  0.2
#
# Sample_folder:  ../../output/CellFlask/Flask_65_1799_44 , Starting_volume:  62.72 , Poured_volume:  62.72 , Stop_angle:  44.0 , Stop_time:  1.8
#
# Sample_folder: ../../output/CellFlask/Flask_140_600_16  Starting_volume: 135.44 , Poured_volume: 75.1767489 , Stop_angle: 16.0 , Stop_time: 0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_110_600_50 , Starting_volume:  106.2375 , Poured_volume:  106.2375 , Stop_angle:  50.0 , Stop_time:  0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_115_1000_46 , Starting_volume:  111.1875 , Poured_volume:  111.1875 , Stop_angle:  46.0 , Stop_time:  1.0
#
# Sample_folder: ../../output/CellFlask/Flask_100_1799_14  Starting_volume: 96.6775 , Poured_volume: 39.7127511 , Stop_angle: 14.0 , Stop_time: 1.8
#
# Sample_folder:  ../../output/CellFlask/Flask_90_1799_32 , Starting_volume:  86.865 , Poured_volume:  86.865 , Stop_angle:  32.0 , Stop_time:  1.8
#
# Sample_folder: ../../output/CellFlask/Flask_40_600_8  Starting_volume: 38.7675 , Poured_volume: 0.132 , Stop_angle: 8.0 , Stop_time: 0.6
#
# Sample_folder:  ../../output/CellFlask/Flask_135_1799_30 , Starting_volume:  130.565 , Poured_volume:  130.565 , Stop_angle:  30.0 , Stop_time:  1.8
#
# Sample_folder: ../../output/CellFlask/Flask_110_1399_22  Starting_volume: 106.2375 , Poured_volume: 89.44924670000002 , Stop_angle: 22.0 , Stop_time: 1.4
#
# Sample_folder: ../../output/CellFlask/Flask_40_1399_14  Starting_volume: 38.7675 , Poured_volume: 5.6485 , Stop_angle: 14.0 , Stop_time: 1.4

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_medium = pd.read_csv('summary_medium.csv', skiprows=[0,1])

# select randomly 50 rows from the summary_flask dataframe
summary_medium = summary_medium.sample(n=50)

# write to new csv file
# add first row with column names
summary_medium.to_csv('summary_medium_test.csv', header=['scene_number','path','rotationSpeed','stop_angle','pause_time','volume_start','volume_poured','volume_received','spilled_volume'], index=False)

#'real_poured_volume', 'real_received_volume', 'real_spilled_volume'

# add the real_poured_volume, real_received_volume, real_spilled_volume columns
summary_medium = pd.read_csv('summary_medium_test.csv')
summary_medium['real_poured_volume'] = summary_medium['volume_poured']*0.0
summary_medium['real_received_volume'] = summary_medium['volume_poured']*0.0
summary_medium['real_spilled_volume'] = summary_medium['volume_poured']*0.0

# write to new csv file
summary_medium.to_csv('summary_medium_test.csv', index=False)
