# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import pandas as pd

# Set font and fontsize globally
matplotlib.rcParams["font.family"] = "Arial"
matplotlib.rcParams["font.size"] = 11

# %%
# iterate over folders in CellFlask

# Specify the path to the parent folder
parent_folder = "CellFlask"

plt.figure(figsize=(6.3, 3.5))
# Iterate over all entries in the parent folder
for entry in os.scandir(parent_folder):
    if entry.is_dir():
        folder_name = entry.name
        folder_path = entry.path + "/"

        # if folder name starts with 'Flask_45'
        if folder_name.startswith("Flask_35"):
            theta_vs_volume = np.loadtxt(
                folder_path + "theta_vs_volume.txt", delimiter="\t", skiprows=1
            )
            plt.plot(theta_vs_volume[:, 2], theta_vs_volume[:, 0] / 400)

# axis labels
plt.ylabel("Remaining Volume (mL)")
plt.xlabel("Time (s)")
plt.title("Time vs. Volume in Pouring Cell Flask with 35 mL Start Volume")
plt.tight_layout()
plt.savefig("plots/4_2_A_time_vs_volume_flask_35mL.png", dpi=600)
plt.show()

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv("summary_flask.csv", skiprows=[0, 1])

plt.figure(figsize=(6.3, 4))
# make colors of point based on the 7th column with small marker size
plt.scatter(
    summary_flask.iloc[:, 7], summary_flask.iloc[:, 5], c=summary_flask.iloc[:, 3], s=10
)

# plot diagonal line
plt.plot([0, 130], [0, 130], color="black", linestyle="--")

# axis labels
plt.ylabel("Start Volume (mL)")
plt.xlabel("Received Volume (mL)")
plt.title("Received Volume vs. Start Volume for Cell Culture Flask")

# explain colorbar
plt.colorbar(label="Stop Angle (degrees)")
plt.legend(["Data Points", "Received Volume = Start Volume"], loc="lower right")
plt.tight_layout()
plt.savefig("plots/4_2_B_received_vs_starting_volume.png", dpi=600)
plt.show()

# %%
# Specify the path to the parent folder
parent_folder = "CellFlask"

plt.figure(figsize=(6.3, 4))
# Iterate over all entries in the parent folder
for entry in os.scandir(parent_folder):
    if entry.is_dir():
        folder_name = entry.name
        folder_path = entry.path + "/"

        # if folder name starts with 'Flask_45'
        if folder_name.startswith("Flask_20") and folder_name.endswith("20"):
            theta_vs_volume = np.loadtxt(
                folder_path + "theta_vs_volume.txt", delimiter="\t", skiprows=1
            )
            # make color of plot based on the max of the second column

            plt.plot(theta_vs_volume[:, 2], theta_vs_volume[:, 0] / 400)
            # plt.legend([max(theta_vs_volume[:,1])])
            # plt.plot(theta_vs_volume[:,2], theta_vs_volume[:,0]/400)

        # plot the first column of theta_vs_volume against the second column
        # plt.plot(theta_vs_volume[:,2], theta_vs_volume[:,0]/300)

# axis labels
plt.ylabel("Remaining Volume (mL)")
plt.xlabel("Time(s)")

plt.title("Time vs. Volume with Different Stop Times (Stop Angle: 20°)")
plt.tight_layout()
plt.savefig("Plots/4_2_C_time_vs_volume_flask_20degrees.png", dpi=300)
plt.show()

# %%
# Specify the path to the parent folder
parent_folder = "CellFlask"

plt.figure(figsize=(6.3, 4))
# Iterate over all entries in the parent folder
for entry in os.scandir(parent_folder):
    if entry.is_dir():
        folder_name = entry.name
        folder_path = entry.path + "/"

        # if folder name starts with 'Flask_45'
        if "600" in folder_name and folder_name.startswith("Flask_20"):
            theta_vs_volume = np.loadtxt(
                folder_path + "theta_vs_volume.txt", delimiter="\t", skiprows=1
            )
            # make color of plot based on the max of the second column

            plt.plot(theta_vs_volume[:, 2], theta_vs_volume[:, 0] / 400)
            # plt.legend([max(theta_vs_volume[:,1])])
            # plt.plot(theta_vs_volume[:,2], theta_vs_volume[:,0]/400)

        # plot the first column of theta_vs_volume against the second column
        # plt.plot(theta_vs_volume[:,2], theta_vs_volume[:,0]/300)

# axis labels
plt.ylabel("Remaining Volume (mL)")
plt.xlabel("Time(s)")

plt.title("Time vs. Volume with Different Stop Angles (Stop Time: 0.6s)")
plt.tight_layout()
plt.savefig("Plots/4_2_E_time_vs_volume_flask_20degrees.png", dpi=300)
plt.show()

# %%
# Specify the path to the parent folder
parent_folder = "CellFlask"

plt.figure(figsize=(6.3, 4))
# Iterate over all entries in the parent folder
for entry in os.scandir(parent_folder):
    if entry.is_dir():
        folder_name = entry.name
        folder_path = entry.path + "/"

        # if folder name starts with 'Flask_45'
        if folder_name.endswith("200_20"):
            # if folder name contains '600'
            # if '600_20' in folder_name:
            theta_vs_volume = np.loadtxt(
                folder_path + "theta_vs_volume.txt", delimiter="\t", skiprows=1
            )
            # make color of plot based on the max of the second column

            plt.plot(theta_vs_volume[:, 2], theta_vs_volume[:, 0] / 400)

# axis labels
# cut plot at x = 22
plt.xlim(0, 23)
plt.ylabel("Remaining Volume in Pouring Flask (mL)")
plt.xlabel("Time (s)")
plt.title("Time vs. Volume for 20° Stop Angle and 0.2s Stop Time")
plt.tight_layout()
plt.savefig("plots/4_2_D_time_vs_volume_flask_20degrees_200ms.png", dpi=600)
plt.show()

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv("summary_flask.csv", skiprows=[0, 1])

# plt.figure(figsize=(6.3, 5))
# make colors of point based on the 7th column with small marker size
spilled_volume = summary_flask.iloc[:, 8]

# -4 until it is 0
spilled_volume = spilled_volume - 4

print(max(spilled_volume))
# get index of max value
print(np.argmax(spilled_volume))

# get parameters of pour with max spilled volume
print(summary_flask.iloc[np.argmax(spilled_volume), :])


for i in range(len(spilled_volume)):
    if spilled_volume[i] < 0:
        spilled_volume[i] = 0

input_volume = summary_flask.iloc[:, 7]

plt.figure(figsize=(6.3, 3.5))

# plot the spilled volume against the input volume
plt.scatter(input_volume, spilled_volume, c=summary_flask.iloc[:, 3], s=10)

# axis labels
plt.ylabel("Spilled Volume (mL)")
plt.xlabel("Received Volume (mL)")
plt.title("Received Volume vs. Spilled Volume for Cell Flask")
# explain colorbar
plt.colorbar(label="Stop Angle (degrees)")
plt.tight_layout()
plt.savefig("plots/4_2_I_spilled_vs_received_volume.png", dpi=600)
plt.show()
# Out:
# 11.88
# 3405
# 1                                                                           2900
# ../../output/CellFlask/Flask_15_200_2    ../../output/CellFlask/Flask_150_200_50
# 0.030000                                                                    0.03
# 2.000000                                                                    50.0
# 0.200000                                                                     0.2
# 14.692500                                                                 144.92
# 0.002500                                                              144.214996
# 0.002500.1                                                            128.335007
# 0.000000                                                                   15.88
# Name: 3405, dtype: object

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv("summary_flask.csv", skiprows=[0, 1])

# plt.scatter(summary_flask.iloc[:,7], summary_flask.iloc[:,5], c=summary_flask.iloc[:,3], s=10)

received_volume = summary_flask.iloc[:, 7]
start_volume = summary_flask.iloc[:, 5]

start_volumes = []
received_volume_tem = []
possible_output_volumes = []

for i in range(len(received_volume)):
    if round(start_volume[i]) not in start_volumes:
        start_volumes.append(round(start_volume[i]))
        if received_volume_tem != []:
            # possible_output_volumes = np.linspace(0, round(max(received_volume_tem)),)
            possible_output_volumes = np.arange(0, round(max(received_volume_tem)), 1)
            # print(possible_output_volumes)
            received_volume_tem = np.array(received_volume_tem)
            # sort the received volume
            received_volume_tem = np.sort(received_volume_tem)
            # print(received_volume_tem)
            # calculate coverage of possible output volumes
            coverage = []
            for j in range(len(received_volume_tem)):
                if (
                    round(received_volume_tem[j]) in possible_output_volumes
                    and round(received_volume_tem[j]) not in coverage
                ):
                    coverage.append(round(received_volume_tem[j]))
            # print(coverage)
            # print(possible_output_volumes)
            # max_distance_coverage = np.mean(np.diff(coverage))
            # print(max_distance_coverage)
            # print("Coverage in percent:", round(len(coverage)/len(possible_output_volumes)*100, 2), "%")
            # get the max distance between two consecutive points
            max_distance = np.max(np.diff(received_volume_tem))
            # get the mean distance between two consecutive points
            mean_distance = np.mean(np.diff(received_volume_tem))
            print(
                "Start volume",
                round(start_volume[i - 1]),
                ", Max distance:",
                round(max_distance, 2),
                "mL, Mean distance:",
                round(mean_distance, 2),
                "mL, Coverage:",
                round(len(coverage) / len(possible_output_volumes) * 100, 2),
                "%",
            )
            received_volume_tem = []

    received_volume_tem.append(received_volume[i])
# Out:
# Start volume 15 , Max distance: 0.49 mL, Mean distance: 0.11 mL, Coverage: 100.0 %
# Start volume 20 , Max distance: 0.71 mL, Mean distance: 0.15 mL, Coverage: 100.0 %
# Start volume 24 , Max distance: 0.94 mL, Mean distance: 0.19 mL, Coverage: 100.0 %
# Start volume 29 , Max distance: 1.22 mL, Mean distance: 0.23 mL, Coverage: 92.86 %
# Start volume 34 , Max distance: 1.46 mL, Mean distance: 0.25 mL, Coverage: 87.88 %
# Start volume 39 , Max distance: 1.78 mL, Mean distance: 0.3 mL, Coverage: 92.11 %
# Start volume 43 , Max distance: 2.06 mL, Mean distance: 0.34 mL, Coverage: 90.48 %
# Start volume 48 , Max distance: 2.16 mL, Mean distance: 0.38 mL, Coverage: 85.11 %
# Start volume 53 , Max distance: 2.47 mL, Mean distance: 0.42 mL, Coverage: 80.77 %
# Start volume 58 , Max distance: 2.77 mL, Mean distance: 0.45 mL, Coverage: 83.93 %
# Start volume 63 , Max distance: 3.02 mL, Mean distance: 0.49 mL, Coverage: 80.33 %
# Start volume 68 , Max distance: 3.32 mL, Mean distance: 0.53 mL, Coverage: 80.3 %
# Start volume 72 , Max distance: 3.52 mL, Mean distance: 0.57 mL, Coverage: 74.29 %
# Start volume 77 , Max distance: 3.82 mL, Mean distance: 0.61 mL, Coverage: 72.0 %
# Start volume 82 , Max distance: 4.04 mL, Mean distance: 0.64 mL, Coverage: 67.5 %
# Start volume 87 , Max distance: 4.39 mL, Mean distance: 0.68 mL, Coverage: 68.24 %
# Start volume 92 , Max distance: 4.83 mL, Mean distance: 0.72 mL, Coverage: 62.92 %
# Start volume 97 , Max distance: 5.06 mL, Mean distance: 0.76 mL, Coverage: 60.64 %
# Start volume 102 , Max distance: 5.49 mL, Mean distance: 0.79 mL, Coverage: 62.24 %
# Start volume 106 , Max distance: 5.78 mL, Mean distance: 0.82 mL, Coverage: 59.8 %
# Start volume 111 , Max distance: 6.1 mL, Mean distance: 0.86 mL, Coverage: 57.94 %
# Start volume 116 , Max distance: 6.38 mL, Mean distance: 0.89 mL, Coverage: 56.36 %
# Start volume 121 , Max distance: 6.54 mL, Mean distance: 0.92 mL, Coverage: 56.14 %
# Start volume 126 , Max distance: 6.79 mL, Mean distance: 0.94 mL, Coverage: 55.56 %
# Start volume 131 , Max distance: 7.07 mL, Mean distance: 0.97 mL, Coverage: 53.72 %
# Start volume 135 , Max distance: 7.27 mL, Mean distance: 0.99 mL, Coverage: 52.85 %
# Start volume 140 , Max distance: 7.28 mL, Mean distance: 1.01 mL, Coverage: 53.17 %

# %%
# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv("summary_flask.csv", skiprows=[0, 1])

# plt.figure(figsize=(6.3, 5))
# make colors of point based on the 7th column with small marker size
spilled_volume = summary_flask.iloc[:, 8]
start_volume = summary_flask.iloc[:, 5]
received_volume = summary_flask.iloc[:, 7]


# -4 until it is 0
spilled_volume = spilled_volume - 4

for i in range(len(spilled_volume)):
    if spilled_volume[i] < 0:
        spilled_volume[i] = 0

input_volume = summary_flask.iloc[:, 7]

plt.figure(figsize=(6.3, 3.5))

# plot the spilled volume against the input volume
plt.scatter(input_volume, spilled_volume, c=summary_flask.iloc[:, 3], s=10)

# axis labels
plt.ylabel("Spilled Volume (mL)")
plt.xlabel("Received Volume (mL)")
plt.title("Received Volume vs. Spilled Volume for Cell Flask")
# explain colorbar
plt.colorbar(label="Stop Angle (degrees)")
plt.tight_layout()
plt.savefig("plots/4_2_I_spilled_vs_received_volume.png", dpi=600)
plt.show()

# %%
import numpy as np

possible_start_volumes = np.arange(15, 140)  # Array of start volumes from 1 to 150 ml
output_volumes = []
start_volumes = []
min_losses = []

# load the data from summary_flask.csv and skip rows 0 and 1 using pandas library
summary_flask = pd.read_csv("summary_flask.csv", skiprows=[0, 1])


for start_volume in possible_start_volumes:
    for i in range(start_volume + 1):
        start_volumes.append(
            start_volume
        )  # Array of output volumes from 0 to start_volume ml in steps of 1 ml
        output_volumes.append(i)

        start = start_volume
        target = i

        min_loss = 100000

        # iterate thorugh all rows of summary_flask
        for j in range(len(summary_flask)):
            loss = (
                abs(summary_flask.iloc[j, 5] - start)
                + abs(summary_flask.iloc[j, 7] - target)
                + summary_flask.iloc[j, 8] * 0.3
            )
            if loss < min_loss:
                min_loss = loss

        min_losses.append(min_loss)

    print("Percentage done:", round((start_volume - 15) / 125 * 100, 2), "%")

    # start_volumes.append(start_volume)  # Array of start volumes from 1 to 150 ml
    # output_volumes.append(np.arange(0, start_volume + 1))  # Array of output volumes from 0 to start_volume ml in steps of 1 ml

    # print(start_volumes)
    # print(output_volumes)

# array = np.column_stack((start_volumes, output_volumes))  # Combine start_volumes and output_volumes into a single array
# print(output_volumes)
# print(array)

# make scatter plot with start volumes on y-axis and output volumes on x-axis and color based on min_losses, low min_losses are green, high min_losses are red
plt.figure(figsize=(6.3, 4))
plt.scatter(output_volumes, start_volumes, c=min_losses, cmap="RdYlGn_r", s=10)

# axis labels
plt.ylabel("Start Volume (mL)")
plt.xlabel("Target Volume (mL)")
plt.title("Miminal Losses depending on Start and Target Volumes")
# explain colorbar
# plt.colorbar(label='Minimum Loss (mL)')
plt.colorbar(label="Minimum Loss (mL)", format=matplotlib.ticker.LogFormatter())

plt.tight_layout()
plt.show()
# Out:
# Percentage done: 0.0 %
# Percentage done: 0.8 %
# Percentage done: 1.6 %
# Percentage done: 2.4 %
# Percentage done: 3.2 %
# Percentage done: 4.0 %
# Percentage done: 4.8 %
# Percentage done: 5.6 %
# Percentage done: 6.4 %
# Percentage done: 7.2 %
# Percentage done: 8.0 %
# Percentage done: 8.8 %
# Percentage done: 9.6 %
# Percentage done: 10.4 %
# Percentage done: 11.2 %
# Percentage done: 12.0 %
# Percentage done: 12.8 %
# Percentage done: 13.6 %
# Percentage done: 14.4 %
# Percentage done: 15.2 %
# Percentage done: 16.0 %
# Percentage done: 16.8 %
# Percentage done: 17.6 %
# Percentage done: 18.4 %
# Percentage done: 19.2 %
# Percentage done: 20.0 %
# Percentage done: 20.8 %
# Percentage done: 21.6 %
# Percentage done: 22.4 %
# Percentage done: 23.2 %
# Percentage done: 24.0 %
# Percentage done: 24.8 %
# Percentage done: 25.6 %
# Percentage done: 26.4 %
# Percentage done: 27.2 %
# Percentage done: 28.0 %
# Percentage done: 28.8 %
# Percentage done: 29.6 %
# Percentage done: 30.4 %
# Percentage done: 31.2 %
# Percentage done: 32.0 %
# Percentage done: 32.8 %
# Percentage done: 33.6 %
# Percentage done: 34.4 %
# Percentage done: 35.2 %
# Percentage done: 36.0 %
# Percentage done: 36.8 %
# Percentage done: 37.6 %
# Percentage done: 38.4 %
# Percentage done: 39.2 %
# Percentage done: 40.0 %
# Percentage done: 40.8 %
# Percentage done: 41.6 %
# Percentage done: 42.4 %
# Percentage done: 43.2 %
# Percentage done: 44.0 %
# Percentage done: 44.8 %
# Percentage done: 45.6 %
# Percentage done: 46.4 %
# Percentage done: 47.2 %
# Percentage done: 48.0 %
# Percentage done: 48.8 %
# Percentage done: 49.6 %
# Percentage done: 50.4 %
# Percentage done: 51.2 %
# Percentage done: 52.0 %
# Percentage done: 52.8 %
# Percentage done: 53.6 %
# Percentage done: 54.4 %
# Percentage done: 55.2 %
# Percentage done: 56.0 %
# Percentage done: 56.8 %
# Percentage done: 57.6 %
# Percentage done: 58.4 %
# Percentage done: 59.2 %
# Percentage done: 60.0 %
# Percentage done: 60.8 %
# Percentage done: 61.6 %
# Percentage done: 62.4 %
# Percentage done: 63.2 %
# Percentage done: 64.0 %
# Percentage done: 64.8 %
# Percentage done: 65.6 %
# Percentage done: 66.4 %
# Percentage done: 67.2 %
# Percentage done: 68.0 %
# Percentage done: 68.8 %
# Percentage done: 69.6 %
# Percentage done: 70.4 %
# Percentage done: 71.2 %
# Percentage done: 72.0 %
# Percentage done: 72.8 %
# Percentage done: 73.6 %
# Percentage done: 74.4 %
# Percentage done: 75.2 %
# Percentage done: 76.0 %
# Percentage done: 76.8 %
# Percentage done: 77.6 %
# Percentage done: 78.4 %
# Percentage done: 79.2 %
# Percentage done: 80.0 %
# Percentage done: 80.8 %
# Percentage done: 81.6 %
# Percentage done: 82.4 %
# Percentage done: 83.2 %
# Percentage done: 84.0 %
# Percentage done: 84.8 %
# Percentage done: 85.6 %
# Percentage done: 86.4 %
# Percentage done: 87.2 %
# Percentage done: 88.0 %
# Percentage done: 88.8 %
# Percentage done: 89.6 %
# Percentage done: 90.4 %
# Percentage done: 91.2 %
# Percentage done: 92.0 %
# Percentage done: 92.8 %
# Percentage done: 93.6 %
# Percentage done: 94.4 %
# Percentage done: 95.2 %
# Percentage done: 96.0 %
# Percentage done: 96.8 %
# Percentage done: 97.6 %
# Percentage done: 98.4 %
# Percentage done: 99.2 %

# %%
output_volumes_plot = output_volumes
start_volumes_plot = start_volumes
min_losses_plot = min_losses

# %%
# print size of output_volumes_plot
print(len(output_volumes_plot))
print(max(min_losses_plot[0 : round(4 / 6 * len(min_losses_plot))]))
print(np.mean(min_losses_plot[0 : round(4 / 6 * len(min_losses_plot))]))
print(max(min_losses_plot))
# Out:
# 9750
# 7.257249000000005
# 1.8068022064615386
# 18.513500999999998

# %%
plt.figure(figsize=(6.3, 4))
plt.scatter(
    output_volumes_plot,
    start_volumes_plot,
    c=(min_losses_plot),
    cmap="RdYlGn_r",
    s=1.5,
    vmin=0,
    vmax=15,
    marker="o",
)

# axis labels
plt.ylabel("Start Volume (mL)")
plt.xlabel("Target Volume (mL)")
plt.title("Miminal Cost depending on Start and Target Volumes")
# explain colorbar
plt.colorbar(label="Minimal Cost (mL)")
plt.tight_layout()
plt.savefig("plots/4_2_J_minimal_cost.png", dpi=600)
plt.show()
